# %% [markdown]
# ### Cloud Sample Exam Questions<br>
#
# ***
#
# <br>
# https://gcp-examquestions.com/gcp-associate-cloud-engineer-practice-exam-part-2/<br>
#
# **Key:**<br>
#
# <font color=pink>Red = got it wrong<br></font>
# <font color=orange>Orange = kind of confusing, need to look at it more<br></font>

# %% [markdown]
# 1. <br>
#     My ans: <br>
#     Answer: <br>
#
# 2. <br>
#     My ans: <br>
#     Answer: <br>
#
# 3. <br>
#     My ans: <br>
#     Answer: <br>
#
# 4. <br>
#     My ans: <br>
#     Answer: <br>
#
# 5. <br>
#     My ans: <br>
#     Answer: <br>
#
# 6. <br>
#     My ans: <br>
#     Answer: <br>
#
# 7. <br>
#     My ans: <br>
#     Answer: <br>
#
# 8. <br>
#     My ans: <br>
#     Answer: <br>
#
# 9. <br>
#     My ans: <br>
#     Answer: <br>
#
# 10. <br>
#     My ans: <br>
#     Answer: <br>
#
# 11. <br>
#     My ans: <br>
#     Answer: <br>
#
# 12. <br>
#     My ans: <br>
#     Answer: <br>
#
# 13. <br>
#     My ans: <br>
#     Answer: <br>
#
# 14. <br>
#     My ans: <br>
#     Answer: <br>
#
# 15. <br>
#     My ans: <br>
#     Answer: <br>
#
# 16. <br>
#     My ans: <br>
#     Answer: <br>
#
# 17. <br>
#     My ans: <br>
#     Answer: <br>
#
# 18. <br>
#     My ans: <br>
#     Answer: <br>
#
# 19. <br>
#     My ans: <br>
#     Answer: <br>
#
# 20. <br>
#     My ans: <br>
#     Answer: <br>
#
# 21. <br>
#     My ans: <br>
#     Answer: <br>
#
# 22. <br>
#     My ans: <br>
#     Answer: <br>
#
# 23. <br>
#     My ans: <br>
#     Answer: <br>
#
# 24. <br>
#     My ans: <br>
#     Answer: <br>
#
# 25. <br>
#     My ans: <br>
#     Answer: <br>
#
# 26. <br>
#     My ans: <br>
#     Answer: <br>
#
# 27. <br>
#     My ans: <br>
#     Answer: <br>
#
# 28. <br>
#     My ans: <br>
#     Answer: <br>
#
# 29. <br>
#     My ans: <br>
#     Answer: <br>
#
# 30. <br>
#     My ans: <br>
#     Answer: <br>
#
# 31. <br>
#     My ans: <br>
#     Answer: <br>
#
# 32. <br>
#     My ans: <br>
#     Answer: <br>
#
# 33. <br>
#     My ans: <br>
#     Answer: <br>
#
# 34. <br>
#     My ans: <br>
#     Answer: <br>
#
# 35. <br>
#     My ans: <br>
#     Answer: <br>
#
# 36. <br>
#     My ans: <br>
#     Answer: <br>
#
# 37. <br>
#     My ans: <br>
#     Answer: <br>
#
# 38. <br>
#     My ans: <br>
#     Answer: <br>
#
# 39. <br>
#     My ans: <br>
#     Answer: <br>
#
# 40. <br>
#     My ans: <br>
#     Answer: <br>
#
# 41. <br>
#     My ans: <br>
#     Answer: <br>
#
# 42. <br>
#     My ans: <br>
#     Answer: <br>
#
# 43. <br>
#     My ans: <br>
#     Answer: <br>
#
# 44. <br>
#     My ans: <br>
#     Answer: <br>
#
# 45. <br>
#     My ans: <br>
#     Answer: <br>
#
# 46. <br>
#     My ans: <br>
#     Answer: <br>
#
# 47. <br>
#     My ans: <br>
#     Answer: <br>
#
# 48. <br>
#     My ans: <br>
#     Answer: <br>
#
# 49. <br>
#     My ans: <br>
#     Answer: <br>
#
# 50. <br>
#     My ans: <br>
#     Answer: <br>
#
# 99. <br>
#     My ans: <br>
#     Answer: <br>

# %% [markdown]
# 1. A        WRONG D - enable auto scale min/max 1 (the question asked for a single instance)
# 2. D *      OK
# 3. C *      OK
# 4. A *      WRONG B - use HTTPS Loadbalancer
# 5. D        WRONG C - use MIG across zones + autoscale
# 6. B        WRONG D - docker image push to GCR(container Registry), create YAML kubernetes deployment, use the imag and apply -f to deploy
# 7. C        OK
# 8. D *      WRONG A - add metadata flag
# 9.
# 10. C D     OK
# 11.
# 12. D       OK
# 13. B *     WRONG A - 2 external table on bigquery, link it to bigTable, Storage, use bigquery to join the two and search
# 14. B       OK
# 15. C       WRONG? C E F
# 16. B E     OK
# 17. B       WRONG C - use granular ACLs on the bucket
# 18. B       WRONG A - create a new proj + app engine instance
# 19. A *     OK - install emulation using gcloud components
# 20. A *     WRONG D - gcloud app ver migrate v3 -service "pt-createOrder"
# 21. A       WRONG D - replace with max-unavailable 0 -max-surge 1 - to replace startup script
# 22.
# 23. B       WRONG A - coldline, focus is on minimize cost
# 24. C       OK
# 25. A or D  OK A - gcloud compute instance list-filter="zone"
# 26. B       WRONG C - gcloud compute instance-groups rolling-action start-update -max-surge 1 -max-unavailable 0
# 27. D       OK
# 28. B       WRONG D -
# 29. same Q
# 30. B       OK
# 31. A       OK
# 32. B       OK
# 33. C or A  WRONG B - Cloud Spanner - global audience relational DB
# 34. D       OK
# 35. A       OK
# 36. D       WRONG B -
# 37. D       OK
# 38. C       OK
# 39. B       OK
# 40. D       OK
# 41. A       OK
# 42. A       OK
# 43.
# 44. B       OK
# 45. C       WRONG B - use parallel uploads (speed up process, not cost effective)
# 46. D       WRONG A - cloud run for anthos - serverless coding
# 47. E       WRONG B C - load logs to bigquery, upload to cloud storage
# 48. A       WRONG D -
# 49. D       WRONG C - create new GCP project and delete old one
# 50. A       OK
