# %% [markdown]
# ### Cloud Sample Exam Questions<br>
#
# ***
#
# <br>

# %% [markdown]
# **Key:**<br>
#
# <font color=pink>Red = got it wrong<br></font>
# <font color=orange>Orange = kind of confusing, need to look at it more<br></font>

# %% [markdown]
# 1. co-worker need to deploynew ver. of your app to App Engine. Which IAM perm to give?<br>
#     My ans: c - app engine deployer<br>
#     Answer: c - app engine deployer<br>
#
# 2. there's monthly budget reserved and what to be informed. what to do?<br>
#     My ans: B - create a budget alert for 50, 90, 100%<br>
#     Answer: B - create a budget alert for 50, 90, 100%<br>
#
# 3. you want to list all bigquery jobs for that project, what to do?<br>
#     My ans: A - set 'gcloud config set project'<br>
#     Answer: A - set 'gcloud config set project'<br>
#
# 4. Project is in EU-West1 region. You want to set EU-West1 as default, what to do?<br>
#     My ans: B - set "gcloud config set compute/region europe-west1"<br>
#     Answer: B - set "gcloud config set compute/region europe-west1"<br>
#
# 5. How to estimate the cost of running the app as accurately as possible?<br>
#     My ans: C - Use pricing calculator for App Engine<br>
#     Answer: C - Use pricing calculator for App Engine<br>
#
# <font color = orange>
#
# 6. Total data is several petabytes, things need to be written and changed at high speed. What to use?<br>
#     My ans: C - Cloud BigTable<br>
#     Answer: C - Cloud BigTable<br>
# D - was BigQuery.. not sure what it's for yet..<br>
#
# </font>
#
# <font color = pink>
#
# 7. App features user upload and share with other users, has to be up for 30 days, then removed. What to use?<br>
#     My ans: B or D, but D - A managed instance group of filestore servers<br>
#     Answer: B - A multi-regional Cloud Storage Bucket<br>
# buckets can be multi-regional and have lifecycle management.<br>
#
# </font>
#
# 8. instance template that contains web app. It scales based on HTTP traffics, What to use?<br>
#     My ans: A or C, but C - Manage instance group based on template, configure autoscaling based on HTTP traffic<br>
#     Answer: C - Manage instance group based on template, configure autoscaling based on HTTP traffic<br>
# A - was to create VM from instance template. Which seems to be using too much resources.<br>
#
# 9. Created Kubernetes Engine cluster to deploy pods. All container logs must be stored in BigQuery, What to do?<br>
#     My ans: A - turn on stackdriver logging during cluster creation<br>
#     Answer: A - turn on stackdriver logging during cluster creation<br>
# Kinda got lucky on this one, need to learn what stackdriver is<br>
#
# 10. Need Kubernetes cluster that autoscales based on workers #. What to do?<br>
#     My ans: A? - create a cluster on Kubernetes engine and enable autoscaling<br>
#     Answer: A - create a cluster on Kubernetes engine and enable autoscaling<br>
#
# <font color = pink>
#
# 11. an app server running in EU-WE1-d, need to replicate to EU-WE2-c with fewest step possible<br>
#     My ans: D? - gcloud compute instance move --destination-zone europe-west2-c<br>
#     Answer: A - Create a snapshot from disk, create a disk from snapshot in EU-WE2, create a new VM with that disk<br>
# </font>
#
# 12. global app that has transactional, relational data storage<br>
#     My ans: B or E, but B? - Cloud SQL<br>
#     Answer: B - Cloud SQL, because it handles relational data<br>
#
# <font color = pink>
#
# 13. cluster receives many traffics and need to grow, we add a node, what to do?<br>
#     My ans: B - kubectl container clusters resize<br>
#     Answer: A - gcloud container clusters resize<br>
# kinda close, should've realized container clusters uses gcloud command<br>
# </font>
#
# 14. an update for your app, but without impacting users, rollback if any errors, what to do?<br>
#     My ans: ??? hard one.. D seems like the smartest option - migrate traffic to the new ver.<br>
#     or maybe C<br>
#     Answer: D - deploy the update as a new ver. and migrate traffic<br>
#
# 15. Kubernetes deployment with 3 replicas, deployment B need to access A, but A shouldn't be exposed, what to do?<br>
#     My ans: hard one... D.. just a guess<br>
#     Answer: D - this exposes cluster internal IP making it only reachable within the cluster<br>
#
# <font color = pink>
#
# 16. est. of annual cost running bq that runs nightly<br>
#     My ans: D - bq estimate<br>
#     Answer: B - bq query -dry_run to determine the # of bytes read by the query, use this number in pricing calc<br>
# </font>
#
# 17. who in your organization has owner access to a project called "my project"?<br>
#     My ans: B - filter "role:Owner" in IAM page for your project<br>
#     Answer: B - filter "role:Owner" in IAM page for your project<br>
#
# 18. create a new role, current and future projects, role permission: bigquery job user, cloud bigtable user<br>
#     My ans: D? - select both roles and combine into a custom role for organization level<br>
#     Answer: D - select both roles and combine into a custom role for organization level<br>
#
# 19. everyone should view all resources of a specific project<br>
#     My ans: C - new google group, add all user, use 'gcloud projects add-iam-policy-binding'<br>
#     Answer: C - new google group, add all user, use 'gcloud projects add-iam-policy-binding'<br>
# Hella confusing, cause what's the diff between member and user??<br>
# D didn't make sense, because iam role create would be too many roles<br>
#
# 20. need to verify permissions in custom IAM role<br>
#     My ans: A - use GCP console, IAM section<br>
#     Answer: A - use GCP console, IAM section<br>
#
# 21. service for real-time messaging<br>
#     My ans: A - Cloud Pub/Sub<br>
#     Answer: A - Cloud Pub/Sub<br>
#
# 22. Nearline storage tasks would suit:<br>
#     My ans: D? - infrequently read data backups<br>
#     Answer: D - infrequently read data backups<br>
# idk what nearline storage is...<br>
# online and offline archiving<br>
#
# 23. allow you to administer projects through browser based command-line <br>
#     My ans: D - Cloud Shell<br>
#     Answer: D - Cloud Shell<br>
#
# 24. Cloud SQL is based on which DB engine?<br>
#     My ans: B - MySQL<br>
#     Answer: B - MySQL<br>
#
# <font color = pink>
#
# 25. allow you to perform live debugging w/o stopping app?<br>
#     My ans: A or B, but A - App Engine Active Debugger<br>
#     Answer: B - Stackdriver Debugger<br>
# A or B... idk what stackdriver is..<br>
# </font>
#
# 26. not a valid cloud storage class<br>
#     My ans: A - Glacier Storage<br>
#     Answer: A - Glacier Storage<br>
#
# <font color = pink>
#
# 27. allow users to access cloud storage for limited time using specific url<br>
#     My ans: B - Temporary Resources<br>
#     Answer: C - Signed URLs<br>
# idk.. <br>
# </font>
#
# <font color = pink>
#
# 28. which is noSQL database?<br>
#     My ans: D - Cloud Storage<br>
#     Answer: A - Cloud Datastore<br>
# definitely need to study on this<br>
# </font>
#
# 29. which engine allows orchestration of containers?<br>
#     My ans: D - docker<br>
#     Answer: D - docker<br>
#
# 30. which type of IAM are available?<br>
#     My ans: B - primitive and predefined roles<br>
#     Answer: B - primitive and predefined roles<br>
#
# <font color = pink>
#
# 31. which allows you to host a static website?<br>
#     My ans: B - Cloud Endpoint<br>
#     Answer: C - Cloud Storage<br>
# gotta look into this one..<br>
# </font>
#
# 32. open source container engine<br>
#     My ans: B - Kubernetes<br>
#     Answer: B - Kubernetes<br>
#
# 33. cloud source repo provide hosted ver. of which version control system?<br>
#     My ans: A - Git<br>
#     Answer: A - Git<br>
#
# 34. which is analytics data warehouse?<br>
#     My ans: B - BigQuery<br>
#     Answer: B - BigQuery<br>
# I got lucky, but defo need to look into different storage types<br>
#
# 35. ability to create and run VMs<br>
#     My ans: D - Compute Engine<br>
#     Answer: D - Compute Engine<br>
#
# 36. Not helpful for mitigating the impact of unexpected failure<br>
#     My ans: B - configure tags and labels<br>
#     Answer: B - configure tags and labels<br>
#
# 37. allows you to sync data to your google domain with active directory?<br>
#     My ans: A? C is ok, A - Google Cloud Directory Sync (GCDS)<br>
#     Answer: A - Google Cloud Directory Sync (GCDS)<br>
# IDK, gotta look into this<br>
#
# <font color=pink>
#
# 38. allow time limited access to buckets and objects w/o google acct<br>
#     My ans: A or C, but C - Single sign-on<br>
#     Answer: A - Signed URLs<br>
# Keep getting this wrong.... Signed URLs must study<br>
# </font>
#
# 39. a VM instance that can be terminated by Compute Engine w/o warning<br>
#     My ans: A or B, but A - Preemptible VM<br>
#     Answer: A - Preemptible VM<br>
# Preemptible VM is a super cheap VM<br>
#
# 40. what's managed instace group?<br>
#     My ans: B? - Uses instance template and create identical<br>
#     Answer: B - Uses instance template and create identical<br>
# but doesn't always create identical, i thought there was option of customs<br>
#
# <font color=pink>
#
# 41. type of firewall rules Cloud networking support?<br>
#     My ans: D - allow and deny<br>
#     Answer: A - deny<br>
# ok.. kind of confusing question, gotta look into this<br>
#
# Note:<br>
# every network has an implied deny firewall rules for ingress(incoming) traffic<br>
# so gotta set otherwise in high priority to cancel out the default settings<br>
# </font>
#
# 42. how subnetwork differ from legacy network<br>
#     My ans: B - subnet controls IP ranges used for instances that are allocated<br>
#     Answer: B - subnet controls IP ranges used for instances that are allocated<br>
#
# <font color=pink>
#
# 43. not valid metric for triggering autoscale<br>
#     My ans: C? - Stackdriver Monitoring metrics<br>
#     Answer: D - App Engine Task Queues<br>
# idk.. good question<br>
# </font>
#
# 44. apply firewall settings easier?<br>
#     My ans: B or D.., but B - Tags<br>
#     Answer: B - Tags<br>
# wtfs difference between tags and labels?<br>
#
# 45. what does Cloud SQL do for high availability<br>
#     My ans: D - failover replicas<br>
#     Answer: D - failover replicas<br>
# Cloud SQL is covered in later lesson<br>
#
# <font color=pink>
#
# 46. Compute Engine, when executing a startup script on Linux, what user does it execute as?<br>
#     My ans: B - GCEinstance user<br>
#     Answer: D - root<br>
# </font>
#
# <font color=pink>
#
# 47. which method will not cause a shutdown script to be executed?<br>
#     My ans: B - preemptible instance being terminated<br>
#     Answer: C - an instance reset API call<br>
# </font>
#
# 48. which type to use to interact with Google Cloud Services?<br>
#     My ans: B - Service Account<br>
#     Answer: B - Service Account<br>
#
# 49. which is not best IAM practice?<br>
#     My ans: A - use primitive roles<br>
#     Answer: A - use primitive roles<br>
#
# <font color=pink>
#
# 50. which not do to reduce your recovery time in disaster?<br>
#     My ans: C - use highly preconfigured machine image for deploying new instance<br>
#     Answer: D - replace active hybrid production environment with a warm standby server<br>
# </font>

# %% [markdown]
# 51. <br>
#     My ans: <br>
#     Answer: <br>
#
# 99. <br>
#     My ans: <br>
#     Answer: <br>

# %% [markdown]
# **Word Bank:**<br>
#
# **Internet of Things (IoT)** - anything that's connected to the Internet, but it's a small device (Ex. Home Dashboard for frontdoor cam, Navigation in the car dashboard)<br>
#
# **Representational state transfer (REST)** - an architecture style to transfer information through the internet.<br>
# - Identification of resources<br>
# - Manipulation of resources<br>
# - Self-descriptive messages<br>
# - Hypermedia as the engine of application state<br>
#
# in HTTP Methods: Ex. GET, POST, PUT, PATCH, DELETE, OPTIONS<br>
#
# **metadata** - context of what the thing is<br>
#
# **stackdriver** - monitoring, logging, tracing, error, reporting<br>
#
# **Tags** - key/value pair for access controls, does allow/deny access<br>
#
# **Labels** - key/value pair to attach to resources and filter based on it<br>
